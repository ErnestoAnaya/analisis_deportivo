# %%
from xgboost import XGBClassifier, plot_importance

import pandas as pd

# %%
model = XGBClassifier()
model.load_model("model_scores.json")

# %%
plot_importance(model, max_num_features=20)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
model.feature_importances_
# Out:
# array([0.01214397, 0.00455934, 0.        , 0.00161575, 0.00565288,
#        0.        , 0.00778499, 0.01336049, 0.01547238, 0.00439574,
#        0.01299268, 0.03881337, 0.0034919 , 0.        , 0.00201389,
#        0.        , 0.        , 0.        , 0.00494974, 0.        ,
#        0.        , 0.00473933, 0.00524606, 0.00496205, 0.00472453,
#        0.00380413, 0.00185326, 0.00243423, 0.0038739 , 0.00333761,
#        0.00514643, 0.00407353, 0.0044993 , 0.00337203, 0.00668187,
#        0.00588547, 0.        , 0.00329592, 0.        , 0.        ,
#        0.        , 0.00654061, 0.        , 0.        , 0.00428899,
#        0.        , 0.00546543, 0.00374464, 0.00514397, 0.00456252,
#        0.00288366, 0.00424407, 0.00197677, 0.00421814, 0.00331191,
#        0.00285804, 0.00621612, 0.        , 0.00341243, 0.        ,
#        0.00523836, 0.        , 0.        , 0.        , 0.00495127,
#        0.        , 0.        , 0.00190534, 0.00447304, 0.01791412,
# ...
